# %%
import asyncio
from ajayji import SDK
from ajayji.mcp_host import JupyterMCPHost

# 1. Initialize our MCP Host
mcp_host = JupyterMCPHost(name="NotebookServer", port=8000)

# 2. Define a custom Python function and register it as an MCP tool
@mcp_host.tool(name="calculate_complex_math", description="Multiplies a number by 42")
def calculate_complex_math(number: int) -> int:
    print(f"🐍 [Jupyter] Executing native python function with input: {number}")
    return number * 42

# 3. Start the FastMCP Server in the background
mcp_host.start()

async def run_test():
    # 4. Initialize the Ajayji SDK
    sdk = SDK()
    
    agent_id = "test_mcp_agent"
    
    # 5. Provision the Persona using the new SDK method we generated
    print("📡 [SDK] Provisioning Persona with MCP Server...")
    provision_response = await sdk.personas.create_persona_async(
        agent_id=agent_id,
        agent_name="MCP Demo Agent",
        model="llama-3-8b.gguf", # Change this to an actively downloaded model filename you have!
        mcp_servers=["http://127.0.0.1:8000/sse"],
        system_prompt="You have access to a tool called 'calculate_complex_math'. You must use it when asked to perform math."
    )
    print(f"✅ [SDK] Provision Response: {provision_response}")

    # 6. Invoke the Persona, which will trigger the Daemon to connect back to us
    print("🤖 [SDK] Invoking Persona with prompt...")
    invoke_response = await sdk.personas.invoke_persona_async(
        id=agent_id,
        request_body={
            "query": "Please use the calculate_complex_math tool on the number 10 and tell me the result."
        }
    )
    print(f"🎉 [SDK] Final Answer from Model: {invoke_response}")

# Execute the test
if __name__ == "__main__":
    asyncio.run(run_test())
# Out:
# INFO:     Started server process [51273]
# INFO:     Waiting for application startup.
# INFO:     Application startup complete.
# INFO:     Uvicorn running on http://127.0.0.1:8000 (Press CTRL+C to quit)
# ✅ FastMCP Server started in background. SSE URL: http://127.0.0.1:8000/sse
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[1], line 46
#      44 # Execute the test
#      45 if __name__ == "__main__":
# ---> 46     asyncio.run(run_test())
#
# File /opt/anaconda3/lib/python3.13/asyncio/runners.py:191, in run(main, debug, loop_factory)
#     161 """Execute the coroutine and return the result.
#     162
#     163 This function runs the passed coroutine, taking care of
#    (...)
#     187     asyncio.run(main())
#     188 """
#     189 if events._get_running_loop() is not None:
#     190     # fail fast with short traceback
# --> 191     raise RuntimeError(
# ...

# %%
import asyncio
from ajayji import SDK
from ajayji.mcp_host import JupyterMCPHost

# 1. Initialize our MCP Host
mcp_host = JupyterMCPHost(name="NotebookServer", port=8000)

# 2. Define a custom Python function and register it as an MCP tool
@mcp_host.tool(name="calculate_complex_math", description="Multiplies a number by 42")
def calculate_complex_math(number: int) -> int:
    print(f"🐍 [Jupyter] Executing native python function with input: {number}")
    return number * 42

# 3. Start the FastMCP Server in the background
mcp_host.start()

async def run_test():
    # 4. Initialize the Ajayji SDK
    sdk = SDK()
    
    agent_id = "test_mcp_agent"
    
    # 5. Provision the Persona using the new SDK method we generated
    print("📡 [SDK] Provisioning Persona with MCP Server...")
    provision_response = await sdk.personas.create_persona_async(
        agent_id=agent_id,
        agent_name="MCP Demo Agent",
        model="llama-3-8b.gguf", # Change this to an actively downloaded model filename you have!
        mcp_servers=["http://127.0.0.1:8000/sse"],
        system_prompt="You have access to a tool called 'calculate_complex_math'. You must use it when asked to perform math."
    )
    print(f"✅ [SDK] Provision Response: {provision_response}")

    # 6. Invoke the Persona, which will trigger the Daemon to connect back to us
    print("🤖 [SDK] Invoking Persona with prompt...")
    invoke_response = await sdk.personas.invoke_persona_async(
        id=agent_id,
        request_body={
            "query": "Please use the calculate_complex_math tool on the number 10 and tell me the result."
        }
    )
    print(f"🎉 [SDK] Final Answer from Model: {invoke_response}")

# Execute the test directly in Jupyter!
await run_test()
# Out:
# ✅ FastMCP Server started in background. SSE URL: http://127.0.0.1:8000/sse
# INFO:     Started server process [51273]
# INFO:     Waiting for application startup.
# INFO:     Application startup complete.
# ERROR:    [Errno 48] error while attempting to bind on address ('127.0.0.1', 8000): [errno 48] address already in use
# INFO:     Waiting for application shutdown.
# INFO:     Application shutdown complete.
# 📡 [SDK] Provisioning Persona with MCP Server...
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[2], line 45
#      42     print(f"🎉 [SDK] Final Answer from Model: {invoke_response}")
#      44 # Execute the test directly in Jupyter!
# ---> 45 await run_test()
#
# Cell In[2], line 25, in run_test()
#      23 # 5. Provision the Persona using the new SDK method we generated
#      24 print("📡 [SDK] Provisioning Persona with MCP Server...")
# ...

# %%
import asyncio
from ajayji import SDK
from ajayji.mcp_host import JupyterMCPHost

# 1. Initialize our MCP Host (Using 8001 to avoid 'address already in use')
mcp_host = JupyterMCPHost(name="NotebookServer", port=8002)

# 2. Define a custom Python function and register it as an MCP tool
@mcp_host.tool(name="calculate_complex_math", description="Multiplies a number by 42")
def calculate_complex_math(number: int) -> int:
    print(f"🐍 [Jupyter] Executing native python function with input: {number}")
    return number * 42

# 3. Start the FastMCP Server in the background
mcp_host.start()

async def run_test():
    # 4. Initialize the Ajayji SDK
    sdk = SDK()
    
    agent_id = "test_mcp_agent"
    
    # 5. Provision the Persona using the new SDK method we generated
    print("📡 [SDK] Provisioning Persona with MCP Server...")
    provision_response = await sdk.persona_orchestration.create_persona_async(
        agent_id=agent_id,
        agent_name="MCP Demo Agent",
        model="gemma-3-1b-it-Q5_K_M.gguf", # Change this to an actively downloaded model filename you have!
        mcp_servers=["http://127.0.0.1:8002/sse"], # Notice we match port 8001 here!
        system_prompt="You have access to a tool called 'calculate_complex_math'. You must use it when asked to perform math."
    )
    print(f"✅ [SDK] Provision Response: {provision_response}")

    # 6. Invoke the Persona, which will trigger the Daemon to connect back to us
    print("🤖 [SDK] Invoking Persona with prompt...")
    invoke_response = await sdk.persona_orchestration.invoke_persona_async(
        id=agent_id,
        request_body={
            "query": "Please use the calculate_complex_math tool on the number 10 and tell me the result."
        }
    )
    print(f"🎉 [SDK] Final Answer from Model: {invoke_response}")

# Execute the test directly in Jupyter!
await run_test()
# Out:
# ✅ FastMCP Server started in background. SSE URL: http://127.0.0.1:8002/sse
# INFO:     Started server process [70043]
# INFO:     Waiting for application startup.
# INFO:     Application startup complete.
# ERROR:    [Errno 48] error while attempting to bind on address ('127.0.0.1', 8002): [errno 48] address already in use
# INFO:     Waiting for application shutdown.
# INFO:     Application shutdown complete.
# 📡 [SDK] Provisioning Persona with MCP Server...
# [05/24/26 00:45:39] INFO     HTTP Request: POST http://localhost:14321/api/v1/personas "HTTP/1.1    ]8;id=241512;file:///opt/anaconda3/lib/python3.13/site-packages/httpx/_client.py\_client.py]8;;\:]8;id=296700;file:///opt/anaconda3/lib/python3.13/site-packages/httpx/_client.py#1740\1740]8;;\
#                              200 OK"
# ✅ [SDK] Provision Response: status=None
# 🤖 [SDK] Invoking Persona with prompt...
# ---------------------------------------------------------------------------
# ...

# %%
import asyncio
from ajayji import SDK
from ajayji.mcp_host import JupyterMCPHost

# 1. Initialize our MCP Host with port=0 for automatic free port discovery
mcp_host = JupyterMCPHost(name="NotebookServer", port=0)

# 2. Define a custom Python function and register it as an MCP tool
@mcp_host.tool(name="calculate_complex_math", description="Multiplies a number by 42")
def calculate_complex_math(number: int) -> int:
    print(f"🐍 [Jupyter] Executing native python function with input: {number}")
    return number * 42

# 3. Start the FastMCP Server in the background
mcp_host.start()

async def run_test():
    # 4. Initialize the Ajayji SDK
    sdk = SDK()
    
    agent_id = "test_mcp_agent"
    
    # 5. Provision the Persona using the new SDK method we generated
    print(f"📡 [SDK] Provisioning Persona with MCP Server on port {mcp_host.port}...")
    provision_response = await sdk.persona_orchestration.create_persona_async(
        agent_id=agent_id,
        agent_name="MCP Demo Agent",
        model="gemma-3-1b-it-Q5_K_M.gguf", # Ensure this model is downloaded!
        # Use the dynamically assigned port here!
        mcp_servers=[f"http://127.0.0.1:{mcp_host.port}/sse"], 
        system_prompt="You have access to a tool called 'calculate_complex_math'. You must use it when asked to perform math."
    )
    print(f"✅ [SDK] Provision Response: {provision_response}")

    # 6. Invoke the Persona
    print("🤖 [SDK] Invoking Persona with prompt...")
    invoke_response = await sdk.persona_orchestration.invoke_persona_async(
        id=agent_id,
        request_body={
            "query": "Please use the calculate_complex_math tool on the number 10 and tell me the result."
        }
    )
    print(f"🎉 [SDK] Final Answer from Model: {invoke_response}")

# Execute the test directly in Jupyter!
await run_test()
# Out:
# INFO:     Started server process [78908]
# INFO:     Waiting for application startup.
# INFO:     Application startup complete.
# INFO:     Uvicorn running on http://127.0.0.1:61267 (Press CTRL+C to quit)
# ✅ FastMCP Server started in background. SSE URL: http://127.0.0.1:61267/sse
# 📡 [SDK] Provisioning Persona with MCP Server on port 61267...
# [05/24/26 00:50:29] INFO     HTTP Request: POST http://localhost:14321/api/v1/personas "HTTP/1.1    ]8;id=691108;file:///opt/anaconda3/lib/python3.13/site-packages/httpx/_client.py\_client.py]8;;\:]8;id=919132;file:///opt/anaconda3/lib/python3.13/site-packages/httpx/_client.py#1740\1740]8;;\
#                              200 OK"
# ✅ [SDK] Provision Response: status=None
# 🤖 [SDK] Invoking Persona with prompt...
# INFO:     127.0.0.1:61270 - "GET /sse HTTP/1.1" 200 OK
# ---------------------------------------------------------------------------
# ReadTimeout                               Traceback (most recent call last)
# ...

# %%
import asyncio
from ajayji import SDK
from ajayji.mcp_host import JupyterMCPHost

# 1. Initialize our MCP Host with port=0 for automatic free port discovery
mcp_host = JupyterMCPHost(name="NotebookServer", port=0)

# 2. Define a custom Python function and register it as an MCP tool
@mcp_host.tool(name="calculate_complex_math", description="Multiplies a number by 42")
def calculate_complex_math(number: int) -> int:
    print(f"🐍 [Jupyter] Executing native python function with input: {number}")
    return number * 42

# 3. Start the FastMCP Server in the background
mcp_host.start()

async def run_test():
    # 4. Initialize the Ajayji SDK
    sdk = SDK()
    
    agent_id = "test_mcp_agent"
    
    # 5. Provision the Persona using the new SDK method we generated
    print(f"📡 [SDK] Provisioning Persona with MCP Server on port {mcp_host.port}...")
    provision_response = await sdk.persona_orchestration.create_persona_async(
        agent_id=agent_id,
        agent_name="MCP Demo Agent",
        model="gemma-3-1b-it-Q5_K_M.gguf", 
        mcp_servers=[f"http://127.0.0.1:{mcp_host.port}/sse"], 
        system_prompt="You have access to a tool called 'calculate_complex_math'. You must use it when asked to perform math."
    )
    print(f"✅ [SDK] Provision Response: {provision_response}")

    # 6. Invoke the Persona with an extended timeout!
    print("🤖 [SDK] Invoking Persona with prompt...")
    invoke_response = await sdk.persona_orchestration.invoke_persona_async(
        id=agent_id,
        request_body={
            "query": "Please use the calculate_complex_math tool on the number 10 and tell me the result."
        },
        timeout_ms=60000  # <--- FIX: Allow up to 60 seconds for local LLM inference to complete
    )
    print(f"🎉 [SDK] Final Answer from Model: {invoke_response}")

# Execute the test directly in Jupyter!
await run_test()
# Out:
# INFO:     Started server process [10563]
# INFO:     Waiting for application startup.
# INFO:     Application startup complete.
# INFO:     Uvicorn running on http://127.0.0.1:61882 (Press CTRL+C to quit)
# 🐍 [Jupyter] Starting FastMCP server on port 61882...✅ FastMCP Server started in background. SSE URL: http://127.0.0.1:61882/sse
#
# 📡 [SDK] Provisioning Persona with MCP Server on port 61882...
# [05/24/26 19:27:53] INFO     HTTP Request: POST http://localhost:14321/api/v1/personas "HTTP/1.1    ]8;id=770130;file:///opt/anaconda3/lib/python3.13/site-packages/httpx/_client.py\_client.py]8;;\:]8;id=342110;file:///opt/anaconda3/lib/python3.13/site-packages/httpx/_client.py#1740\1740]8;;\
#                              200 OK"
# ✅ [SDK] Provision Response: status=None
# 🤖 [SDK] Invoking Persona with prompt...
# INFO:     127.0.0.1:61885 - "GET /sse HTTP/1.1" 200 OK
# INFO:     127.0.0.1:61888 - "POST /messages/?session_id=181f80134a0e4c018f7f6aef461cfbf2 HTTP/1.1" 202 Accepted
# ...

# %%
import asyncio
from ajayji import SDK
from ajayji.mcp_host import JupyterMCPHost

# 1. Initialize our MCP Host with port=0 for automatic free port discovery
mcp_host = JupyterMCPHost(name="NotebookServer", port=0)

# 2. Define a custom Python function and register it as an MCP tool
@mcp_host.tool(name="calculate_complex_math", description="Multiplies a number by 42")
def calculate_complex_math(number: int) -> int:
    print(f"🐍 [Jupyter] Executing native python function with input: {number}")
    return number * 42

# 3. Start the FastMCP Server in the background
mcp_host.start()

async def run_test():
    # 4. Initialize the Ajayji SDK
    sdk = SDK()
    
    agent_id = "test_mcp_agent"
    
    # 5. Provision the Persona using the new SDK method we generated
    print(f"📡 [SDK] Provisioning Persona with MCP Server on port {mcp_host.port}...")
    provision_response = await sdk.persona_orchestration.create_persona_async(
        agent_id=agent_id,
        agent_name="MCP Demo Agent",
        model="gemma-3-1b-it-Q5_K_M.gguf", 
        mcp_servers=[f"http://127.0.0.1:{mcp_host.port}/sse"], 
        system_prompt="You have access to a tool called 'calculate_complex_math'. You must use it when asked to perform math."
    )
    print(f"✅ [SDK] Provision Response: {provision_response}")

    # 6. Invoke the Persona with an extended timeout!
    print("🤖 [SDK] Invoking Persona with prompt...")
    invoke_response = await sdk.persona_orchestration.invoke_persona_async(
        id=agent_id,
        request_body={
            "query": "Please use the calculate_complex_math tool on the number 10 and tell me the result."
        },
        timeout_ms=60000 
    )
    print(f"🎉 [SDK] Final Answer from Model: {invoke_response}")

# Execute the test
await run_test()

# 7. STOP the server to prevent infinite pings and free the port!
mcp_host.stop()
# Out:
# 🐍 [Jupyter] Starting FastMCP server on port 56988...✅ FastMCP Server started in background. SSE URL: http://127.0.0.1:56988/sse
# INFO:     Started server process [31337]
# INFO:     Waiting for application startup.
# INFO:     Application startup complete.
# INFO:     Uvicorn running on http://127.0.0.1:56988 (Press CTRL+C to quit)
# 📡 [SDK] Provisioning Persona with MCP Server on port 56988...
# [05/24/26 23:50:56] INFO     HTTP Request: POST http://localhost:14321/api/v1/personas "HTTP/1.1    ]8;id=973179;file:///opt/anaconda3/lib/python3.13/site-packages/httpx/_client.py\_client.py]8;;\:]8;id=978421;file:///opt/anaconda3/lib/python3.13/site-packages/httpx/_client.py#1740\1740]8;;\
#                              200 OK"
# ✅ [SDK] Provision Response: status=None
# 🤖 [SDK] Invoking Persona with prompt...
# INFO:     127.0.0.1:56991 - "GET /sse HTTP/1.1" 200 OK
# INFO:     127.0.0.1:56992 - "POST /messages/?session_id=6c40c8e51a854d94b59cd545b46163a2 HTTP/1.1" 202 Accepted
# ...

# %%
import asyncio
from ajayji import SDK
from ajayji.mcp_host import JupyterMCPHost

# 1. Initialize our MCP Host with port=0 for automatic free port discovery
mcp_host = JupyterMCPHost(name="NotebookServer", port=0)

# 2. Define custom Python functions and register them as MCP tools
@mcp_host.tool(name="calculate_complex_math", description="Multiplies a number by 42")
def calculate_complex_math(number: int) -> int:
    print(f"🐍 [Jupyter] Executing native python function with input: {number}")
    return number * 42

@mcp_host.tool(name="add_ten", description="Adds 10 to a number")
def add_ten(number: int) -> int:
    print(f"🐍 [Jupyter] Executing add_ten with input: {number}")
    return number + 10

# 3. Start the FastMCP Server in the background
mcp_host.start()

async def run_test():
    # 4. Initialize the Ajayji SDK
    sdk = SDK()
    
    agent_id = "test_mcp_stateful_agent"
    
    # 5. Provision the Persona using the SDK
    print(f"📡 [SDK] Provisioning Persona...")
    provision_response = await sdk.persona_orchestration.create_persona_async(
        agent_id=agent_id,
        agent_name="Stateful MCP Demo Agent",
        model="gemma-3-1b-it-Q5_K_M.gguf", 
        # Note: We omit mcp_servers here because we want to connect statefully!
        system_prompt="You have access to tools called 'calculate_complex_math' and 'add_ten'. You must use them when asked to perform math."
    )
    print(f"✅ [SDK] Provision Response: {provision_response}")

    # 6. EXPLICITLY CONNECT to the MCP Server
    # This establishes the SSE connection and does the handshake once.
    print(f"🔗 [SDK] Connecting explicitly to MCP server at {mcp_host.sse_uri}...")
    connect_response = await sdk.mcp_management.connect_async(
        request_body={
            "mcp_servers": [mcp_host.sse_uri]
        }
    )
    print(f"✅ [SDK] Connect Response: {connect_response}")

    try:
        # 7. First Invocation (Should be fast, no handshake needed)
        print("🤖 [SDK] Invocation 1: Calling complex math...")
        invoke_response1 = await sdk.persona_orchestration.invoke_persona_async(
            id=agent_id,
            request_body={
                "query": "Please use the calculate_complex_math tool on the number 10 and tell me the result."
            },
            timeout_ms=60000 
        )
        print(f"🎉 [SDK] Response 1: {invoke_response1}")

        # 8. Second Invocation (Reuses the existing connection)
        print("🤖 [SDK] Invocation 2: Calling add ten...")
        invoke_response2 = await sdk.persona_orchestration.invoke_persona_async(
            id=agent_id,
            request_body={
                "query": "Now use the add_ten tool on the number 5 and tell me the result."
            },
            timeout_ms=60000 
        )
        print(f"🎉 [SDK] Response 2: {invoke_response2}")
        
    finally:
        # 9. EXPLICITLY DISCONNECT
        print("🔌 [SDK] Disconnecting from MCP Server...")
        disconnect_response = await sdk.mcp_management.disconnect_async()
        print(f"✅ [SDK] Disconnect Response: {disconnect_response}")

# Execute the test
await run_test()

# 10. STOP the server to prevent infinite pings and free the port!
mcp_host.stop()
print("Done!")
# Out:
# INFO:     Started server process [54973]
# INFO:     Waiting for application startup.
# INFO:     Application startup complete.
# INFO:     Uvicorn running on http://127.0.0.1:61497 (Press CTRL+C to quit)
# 🐍 [Jupyter] Starting FastMCP server on port 61497...✅ FastMCP Server started in background. SSE URL: http://127.0.0.1:61497/sse
#
# 📡 [SDK] Provisioning Persona...
# [05/25/26 01:15:41] INFO     HTTP Request: POST http://localhost:14321/api/v1/personas "HTTP/1.1    ]8;id=245105;file:///opt/anaconda3/lib/python3.13/site-packages/httpx/_client.py\_client.py]8;;\:]8;id=126712;file:///opt/anaconda3/lib/python3.13/site-packages/httpx/_client.py#1740\1740]8;;\
#                              200 OK"
# ✅ [SDK] Provision Response: status=None
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[1], line 79
# ...

# %%
import asyncio
from ajayji import SDK
from ajayji.mcp_host import JupyterMCPHost

# 1. Initialize our MCP Host with port=0 for automatic free port discovery
mcp_host = JupyterMCPHost(name="NotebookServer", port=0)

# 2. Define custom Python functions and register them as MCP tools
@mcp_host.tool(name="calculate_complex_math", description="Multiplies a number by 42")
def calculate_complex_math(number: int) -> int:
    print(f"🐍 [Jupyter] Executing native python function with input: {number}")
    return number * 42

@mcp_host.tool(name="add_ten", description="Adds 10 to a number")
def add_ten(number: int) -> int:
    print(f"🐍 [Jupyter] Executing add_ten with input: {number}")
    return number + 10

# 3. Start the FastMCP Server in the background
mcp_host.start()

async def run_test():
    # 4. Initialize the Ajayji SDK
    sdk = SDK()
    
    agent_id = "test_mcp_stateful_agent"
    
    # 5. Provision the Persona using the SDK
    print(f"📡 [SDK] Provisioning Persona...")
    provision_response = await sdk.persona_orchestration.create_persona_async(
        agent_id=agent_id,
        agent_name="Stateful MCP Demo Agent",
        model="gemma-3-1b-it-Q5_K_M.gguf", 
        # Note: We omit mcp_servers here because we want to connect statefully!
        system_prompt="You have access to tools called 'calculate_complex_math' and 'add_ten'. You must use them when asked to perform math."
    )
    print(f"✅ [SDK] Provision Response: {provision_response}")

    # 6. EXPLICITLY CONNECT to the MCP Server
    # This establishes the SSE connection and does the handshake once.
    print(f"🔗 [SDK] Connecting explicitly to MCP server at {mcp_host.sse_uri}...")
    connect_response = await sdk.mcp_management.connect_async(
        request_body={
            "mcp_servers": [mcp_host.sse_uri]
        }
    )
    print(f"✅ [SDK] Connect Response: {connect_response}")

    try:
        # 7. First Invocation (Should be fast, no handshake needed)
        print("🤖 [SDK] Invocation 1: Calling complex math...")
        invoke_response1 = await sdk.persona_orchestration.invoke_persona_async(
            id=agent_id,
            request_body={
                "query": "Please use the calculate_complex_math tool on the number 10 and tell me the result."
            },
            timeout_ms=60000 
        )
        print(f"🎉 [SDK] Response 1: {invoke_response1}")

        # 8. Second Invocation (Reuses the existing connection)
        print("🤖 [SDK] Invocation 2: Calling add ten...")
        invoke_response2 = await sdk.persona_orchestration.invoke_persona_async(
            id=agent_id,
            request_body={
                "query": "Now use the add_ten tool on the number 5 and tell me the result."
            },
            timeout_ms=60000 
        )
        print(f"🎉 [SDK] Response 2: {invoke_response2}")
        
    finally:
        # 9. EXPLICITLY DISCONNECT
        print("🔌 [SDK] Disconnecting from MCP Server...")
        disconnect_response = await sdk.mcp_management.disconnect_async()
        print(f"✅ [SDK] Disconnect Response: {disconnect_response}")

# Execute the test
await run_test()

# 10. STOP the server to prevent infinite pings and free the port!
mcp_host.stop()
print("Done!")
# Out:
# INFO:     Started server process [56522]
# INFO:     Waiting for application startup.
# INFO:     Application startup complete.
# INFO:     Uvicorn running on http://127.0.0.1:61820 (Press CTRL+C to quit)
# 🐍 [Jupyter] Starting FastMCP server on port 61820...
# ✅ FastMCP Server started in background. SSE URL: http://127.0.0.1:61820/sse
# 📡 [SDK] Provisioning Persona...
# [05/25/26 01:21:58] INFO     HTTP Request: POST http://localhost:14321/api/v1/personas "HTTP/1.1    ]8;id=805173;file:///opt/anaconda3/lib/python3.13/site-packages/httpx/_client.py\_client.py]8;;\:]8;id=183329;file:///opt/anaconda3/lib/python3.13/site-packages/httpx/_client.py#1740\1740]8;;\
#                              200 OK"
# ✅ [SDK] Provision Response: status=None
# 🔗 [SDK] Connecting explicitly to MCP server at http://127.0.0.1:61820/sse...
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ...

# %%
import asyncio
from ajayji import SDK
from ajayji.mcp_host import JupyterMCPHost

# 1. Initialize our MCP Host with port=0 for automatic free port discovery
mcp_host = JupyterMCPHost(name="NotebookServer", port=0)

# 2. Define custom Python functions and register them as MCP tools
@mcp_host.tool(name="calculate_complex_math", description="Multiplies a number by 42")
def calculate_complex_math(number: int) -> int:
    print(f"🐍 [Jupyter] Executing native python function with input: {number}")
    return number * 42

@mcp_host.tool(name="add_ten", description="Adds 10 to a number")
def add_ten(number: int) -> int:
    print(f"🐍 [Jupyter] Executing add_ten with input: {number}")
    return number + 10

# 3. Start the FastMCP Server in the background
mcp_host.start()

async def run_test():
    # 4. Initialize the Ajayji SDK
    sdk = SDK()
    
    agent_id = "test_mcp_stateful_agent"
    
    # 5. Provision the Persona using the SDK
    print(f"📡 [SDK] Provisioning Persona...")
    provision_response = await sdk.persona_orchestration.create_persona_async(
        agent_id=agent_id,
        agent_name="Stateful MCP Demo Agent",
        model="gemma-3-1b-it-Q5_K_M.gguf", 
        # Note: We omit mcp_servers here because we want to connect statefully!
        system_prompt="You have access to tools called 'calculate_complex_math' and 'add_ten'. You must use them when asked to perform math."
    )
    print(f"✅ [SDK] Provision Response: {provision_response}")

    # 6. EXPLICITLY CONNECT to the MCP Server
    # This establishes the SSE connection and does the handshake once.
    print(f"🔗 [SDK] Connecting explicitly to MCP server at {mcp_host.sse_uri}...")
    
    # FIX: Use the Speakeasy generated method name
    connect_response = await sdk.mcp_management.post_api_v1_mcp_connect_async(
        request_body={
            "mcp_servers": [mcp_host.sse_uri]
        }
    )
    print(f"✅ [SDK] Connect Response: {connect_response}")

    try:
        # 7. First Invocation (Should be fast, no handshake needed)
        print("🤖 [SDK] Invocation 1: Calling complex math...")
        invoke_response1 = await sdk.persona_orchestration.invoke_persona_async(
            id=agent_id,
            request_body={
                "query": "Please use the calculate_complex_math tool on the number 10 and tell me the result."
            },
            timeout_ms=60000 
        )
        print(f"🎉 [SDK] Response 1: {invoke_response1}")

        # 8. Second Invocation (Reuses the existing connection)
        print("🤖 [SDK] Invocation 2: Calling add ten...")
        invoke_response2 = await sdk.persona_orchestration.invoke_persona_async(
            id=agent_id,
            request_body={
                "query": "Now use the add_ten tool on the number 5 and tell me the result."
            },
            timeout_ms=60000 
        )
        print(f"🎉 [SDK] Response 2: {invoke_response2}")
        
    finally:
        # 9. EXPLICITLY DISCONNECT
        print("🔌 [SDK] Disconnecting from MCP Server...")
        # FIX: Use the Speakeasy generated method name
        disconnect_response = await sdk.mcp_management.post_api_v1_mcp_disconnect_async()
        print(f"✅ [SDK] Disconnect Response: {disconnect_response}")

# Execute the test
await run_test()

# 10. STOP the server to prevent infinite pings and free the port!
mcp_host.stop()
print("Done!")
# Out:
# 🐍 [Jupyter] Starting FastMCP server on port 61904...✅ FastMCP Server started in background. SSE URL: http://127.0.0.1:61904/sse
# INFO:     Started server process [56522]
# INFO:     Waiting for application startup.
# INFO:     Application startup complete.
# INFO:     Uvicorn running on http://127.0.0.1:61904 (Press CTRL+C to quit)
# 📡 [SDK] Provisioning Persona...
# [05/25/26 01:23:58] INFO     HTTP Request: POST http://localhost:14321/api/v1/personas "HTTP/1.1    ]8;id=721638;file:///opt/anaconda3/lib/python3.13/site-packages/httpx/_client.py\_client.py]8;;\:]8;id=897578;file:///opt/anaconda3/lib/python3.13/site-packages/httpx/_client.py#1740\1740]8;;\
#                              200 OK"
# ✅ [SDK] Provision Response: status=None
# 🔗 [SDK] Connecting explicitly to MCP server at http://127.0.0.1:61904/sse...
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ...

# %%
import asyncio
import logging
from ajayji import SDK
from ajayji.mcp_host import JupyterMCPHost

# --- ADD THIS BLOCK ---
# Suppress warnings from the underlying MCP session logger
logging.getLogger("mcp").setLevel(logging.ERROR)
logging.getLogger("mcp.server.session").setLevel(logging.ERROR)
logging.getLogger("mcp.shared.session").setLevel(logging.ERROR)
# ----------------------

# 1. Initialize our MCP Host with port=0 for automatic free port discovery
mcp_host = JupyterMCPHost(name="NotebookServer", port=0)

# 2. Define custom Python functions and register them as MCP tools
@mcp_host.tool(name="calculate_complex_math", description="Multiplies a number by 42")
def calculate_complex_math(number: int) -> int:
    print(f"🐍 [Jupyter] Executing native python function with input: {number}")
    return number * 42

@mcp_host.tool(name="add_ten", description="Adds 10 to a number")
def add_ten(number: int) -> int:
    print(f"🐍 [Jupyter] Executing add_ten with input: {number}")
    return number + 10

# 3. Start the FastMCP Server in the background
mcp_host.start()

async def run_test():
    # 4. Initialize the Ajayji SDK
    sdk = SDK()
    
    agent_id = "test_mcp_stateful_agent"
    
    # 5. Provision the Persona using the SDK
    print(f"📡 [SDK] Provisioning Persona...")
    provision_response = await sdk.persona_orchestration.create_persona_async(
        agent_id=agent_id,
        agent_name="Stateful MCP Demo Agent",
        model="gemma-3-1b-it-Q5_K_M.gguf", 
        # Note: We omit mcp_servers here because we want to connect statefully!
        system_prompt="You have access to tools called 'calculate_complex_math' and 'add_ten'. You must use them when asked to perform math."
    )
    print(f"✅ [SDK] Provision Response: {provision_response}")

    # 6. EXPLICITLY CONNECT to the MCP Server
    # This establishes the SSE connection and does the handshake once.
    print(f"🔗 [SDK] Connecting explicitly to MCP server at {mcp_host.sse_uri}...")
    
    # FIX: Pass mcp_servers directly, not nested inside request_body
    connect_response = await sdk.mcp_management.post_api_v1_mcp_connect_async(
        mcp_servers=[mcp_host.sse_uri]
    )
    print(f"✅ [SDK] Connect Response: {connect_response}")

    try:
        # 7. First Invocation (Should be fast, no handshake needed)
        print("🤖 [SDK] Invocation 1: Calling complex math...")
        invoke_response1 = await sdk.persona_orchestration.invoke_persona_async(
            id=agent_id,
            request_body={
                "query": "Please use the calculate_complex_math tool on the number 10 and tell me the result."
            },
            timeout_ms=60000 
        )
        print(f"🎉 [SDK] Response 1: {invoke_response1}")

        # 8. Second Invocation (Reuses the existing connection)
        print("🤖 [SDK] Invocation 2: Calling add ten...")
        invoke_response2 = await sdk.persona_orchestration.invoke_persona_async(
            id=agent_id,
            request_body={
                "query": "Now use the add_ten tool on the number 5 and tell me the result."
            },
            timeout_ms=60000 
        )
        print(f"🎉 [SDK] Response 2: {invoke_response2}")
        
    finally:
        # 9. EXPLICITLY DISCONNECT
        print("🔌 [SDK] Disconnecting from MCP Server...")
        disconnect_response = await sdk.mcp_management.post_api_v1_mcp_disconnect_async()
        print(f"✅ [SDK] Disconnect Response: {disconnect_response}")

# Execute the test
await run_test()

# 10. STOP the server to prevent infinite pings and free the port!
mcp_host.stop()
print("Done!")
# Out:
# 🐍 [Jupyter] Starting FastMCP server on port 64636...✅ FastMCP Server started in background. SSE URL: http://127.0.0.1:64636/sse
# INFO:     Started server process [14123]
# INFO:     Waiting for application startup.
# INFO:     Application startup complete.
# INFO:     Uvicorn running on http://127.0.0.1:64636 (Press CTRL+C to quit)
# 📡 [SDK] Provisioning Persona...
# [05/25/26 13:58:40] INFO     HTTP Request: POST http://localhost:14321/api/v1/personas "HTTP/1.1    ]8;id=986360;file:///opt/anaconda3/lib/python3.13/site-packages/httpx/_client.py\_client.py]8;;\:]8;id=298510;file:///opt/anaconda3/lib/python3.13/site-packages/httpx/_client.py#1740\1740]8;;\
#                              200 OK"
# ✅ [SDK] Provision Response: status=None
# 🔗 [SDK] Connecting explicitly to MCP server at http://127.0.0.1:64636/sse...
# INFO:     127.0.0.1:64639 - "GET /sse HTTP/1.1" 200 OK
# INFO:     127.0.0.1:64640 - "POST /messages/?session_id=8125804a5d7d47018f6eb5f583e52182 HTTP/1.1" 202 Accepted
# ...

# %%
import os
from ajayji import SDK

# 1. Initialize the SDK Client
# Ensure the SDK is pointing to your locally running Ajayji daemon port
client = SDK(server_url="http://127.0.0.1:14321")

# 2. Create a new Persona dynamically
print("Creating a new test Persona...")
create_response = client.persona_orchestration.create_persona(
    agent_id="test_display_agent",
    agent_name="Display Test Agent",
    model="gemma-3-1b.gguf",
    system_prompt="You are a test agent."
)

# Extract the newly created Persona ID
# Note: Adjust the attribute access if your SDK returns a different structure
persona_id = create_response.id if hasattr(create_response, 'id') else create_response['id']
print(f"Successfully created Persona with ID: {persona_id}")

# 3. Request and display the canvas!
print(f"Requesting and rendering canvas graphic...")
client.persona_orchestration.display(id=persona_id)
# Out:
# Creating a new test Persona...
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[1], line 19
#      10 create_response = client.persona_orchestration.create_persona(
#      11     agent_id="test_display_agent",
#      12     agent_name="Display Test Agent",
#      13     model="gemma-3-1b.gguf",
#      14     system_prompt="You are a test agent."
#      15 )
#      17 # Extract the newly created Persona ID
#      18 # Note: Adjust the attribute access if your SDK returns a different structure
# ---> 19 persona_id = create_response.id if hasattr(create_response, 'id') else create_response['id']
#      20 print(f"Successfully created Persona with ID: {persona_id}")
#      22 # 3. Request and display the canvas!
#
# TypeError: 'CreatePersonaResponseBody' object is not subscriptable

# %%
# %load_ext autoreload
# %autoreload 2

import asyncio
from ajayji import SDK

async def test_display_canvas():
    # 1. Initialize the Ajayji SDK
    sdk = SDK()
    
    agent_id = "test_canvas_display_agent"
    
    # 2. Provision the Persona using the SDK
    print(f"📡 [SDK] Provisioning Persona '{agent_id}'...")
    provision_response = await sdk.persona_orchestration.create_persona_async(
        agent_id=agent_id,
        agent_name="Canvas Demo Agent",
        model="gemma-3-1b-it-Q5_K_M.gguf", 
        system_prompt="You are a helpful assistant."
    )
    print("✅ [SDK] Provision successful.")

    # 3. Request and display the canvas using the agent_id!
    print(f"🎨 [SDK] Fetching and rendering Canvas PNG...")
    
    # This will render the image directly inline in your Jupyter Notebook
    await sdk.persona_orchestration.display_async(id=agent_id)

# Execute the async test
await test_display_canvas()
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# 📡 [SDK] Provisioning Persona 'test_canvas_display_agent'...
# ✅ [SDK] Provision successful.
# 🎨 [SDK] Fetching and rendering Canvas PNG...

# %%
# %load_ext autoreload
# %autoreload 2

import asyncio
from ajayji import SDK

async def test_iteration_1():
    sdk = SDK()
    agent_id = "test_iter_1"
    
    print(f"📡 [SDK] Provisioning Persona '{agent_id}'...")
    await sdk.persona_orchestration.create_persona_async(
        agent_id=agent_id,
        agent_name="Webhook & Parser Tester",
        model="gemma-3-1b-it-Q5_K_M.gguf",
        system_prompt="You are a helpful assistant.",
        enable_webhook=False,
        input_parser_id="Input Parser test" # Leave blank if you don't have one
    )
    print("✅ [SDK] Provision successful.")
    
    print(f"🎨 [SDK] Fetching and rendering Canvas PNG...")
    await sdk.persona_orchestration.display_async(id=agent_id)

await test_iteration_1()
# Out:
# 📡 [SDK] Provisioning Persona 'test_iter_1'...
# ✅ [SDK] Provision successful.
# 🎨 [SDK] Fetching and rendering Canvas PNG...

# %%
# %load_ext autoreload
# %autoreload 2

import asyncio
import httpx
from ajayji import SDK

async def test_iteration_2():
    sdk = SDK()
    agent_id = "test_iter_2"
    
    # 1. Fetch available tools from the local daemon API
    print("🔍 [SDK] Fetching available tools from local database...")
    async with httpx.AsyncClient() as client:
        response = await client.get("http://localhost:14321/tools/list")
        if response.status_code == 200:
            tools_data = response.json().get('tools', [])
            if not tools_data:
                print("❌ [SDK] You have no tools in your database! Please create a Tool in the Ajayji GUI first.")
                return
            
            # Pick the first available tool ID
            valid_tool_id = tools_data[0]['id']
            valid_tool_name = tools_data[0]['name']
            print(f"✅ [SDK] Found Tool '{valid_tool_name}' with ID: {valid_tool_id}")
        else:
            print("❌ [SDK] Failed to fetch tools from daemon.")
            return

    # 2. Provision Persona using the dynamically fetched Tool ID
    print(f"📡 [SDK] Provisioning Persona '{agent_id}' with Tool ID '{valid_tool_id}'...")
    await sdk.persona_orchestration.create_persona_async(
        agent_id=agent_id,
        agent_name="Tool Routing Tester",
        model="gemma-3-1b-it-Q5_K_M.gguf",
        system_prompt="You are a helpful assistant.",
        tool_ids=[valid_tool_id] # Injecting the valid ID
    )
    print("✅ [SDK] Provision successful.")
    
    # 3. Render Canvas
    print(f"🎨 [SDK] Fetching and rendering Canvas PNG...")
    await sdk.persona_orchestration.display_async(id=agent_id)

await test_iteration_2()
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# 🔍 [SDK] Fetching available tools from local database...
# ✅ [SDK] Found Tool 'test' with ID: tf_51406b68-b936-4a78-8adb-447a995e6d47
# 📡 [SDK] Provisioning Persona 'test_iter_2' with Tool ID 'tf_51406b68-b936-4a78-8adb-447a995e6d47'...
# ✅ [SDK] Provision successful.
# 🎨 [SDK] Fetching and rendering Canvas PNG...

# %%
# %load_ext autoreload
# %autoreload 2

import asyncio
from ajayji import SDK

async def test_iteration_3():
    sdk = SDK()
    agent_id = "test_iter_3"
    
    print(f"📡 [SDK] Provisioning Persona '{agent_id}'...")
    await sdk.persona_orchestration.create_persona_async(
        agent_id=agent_id,
        agent_name="RAG Tester",
        model="gemma-3-1b-it-Q5_K_M.gguf",
        system_prompt="You are a helpful assistant.",
        vector_store_name="my_documents",
        embedding_model_name="embeddinggemma-300m-Q4_0.gguf"
    )
    print("✅ [SDK] Provision successful.")
    
    print(f"🎨 [SDK] Fetching and rendering Canvas PNG...")
    await sdk.persona_orchestration.display_async(id=agent_id)

await test_iteration_3()
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# 📡 [SDK] Provisioning Persona 'test_iter_3'...
# ✅ [SDK] Provision successful.
# 🎨 [SDK] Fetching and rendering Canvas PNG...

# %%
# %load_ext autoreload
# %autoreload 2

import asyncio
import httpx
from ajayji import SDK

async def test_iteration_4():
    sdk = SDK()
    agent_id = "test_iter_4"
    
    # 1. Fetch available events from the local daemon API
    print("🔍 [SDK] Fetching available global events from local database...")
    async with httpx.AsyncClient() as client:
        response = await client.get("http://localhost:14321/events/list")
        if response.status_code == 200:
            events_data = response.json().get('events', [])
            if not events_data:
                print("❌ [SDK] You have no global events in your database! Please create an Event Trigger in the Ajayji GUI first.")
                return
            
            # Pick the first available event ID
            valid_event_id = events_data[0]['id']
            valid_event_name = events_data[0]['name']
            print(f"✅ [SDK] Found Event '{valid_event_name}' with ID: {valid_event_id}")
        else:
            print("❌ [SDK] Failed to fetch events from daemon.")
            return
            
    # 2. Provision Persona using dynamic event ID and auto-provisioned topics
    print(f"📡 [SDK] Provisioning Persona '{agent_id}'...")
    await sdk.persona_orchestration.create_persona_async(
        agent_id=agent_id,
        agent_name="Async Orchestration Tester",
        model="gemma-3-1b-it-Q5_K_M.gguf",
        system_prompt="You are a helpful assistant.",
        input_topic="test_inbound_queue",
        output_topic="test_outbound_queue",
        global_events=[valid_event_id] # Dynamically inject the valid ID
    )
    print("✅ [SDK] Provision successful.")
    
    print(f"🎨 [SDK] Fetching and rendering Canvas PNG...")
    await sdk.persona_orchestration.display_async(id=agent_id)

await test_iteration_4()
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# 🔍 [SDK] Fetching available global events from local database...
# ✅ [SDK] Found Event 'testui' with ID: e020e6ba-2ae7-4fae-82d7-e96ac4e430d7
# 📡 [SDK] Provisioning Persona 'test_iter_4'...
# ✅ [SDK] Provision successful.
# 🎨 [SDK] Fetching and rendering Canvas PNG...

# %%
# %load_ext autoreload
# %autoreload 2

import asyncio
import httpx
from ajayji import SDK

async def test_iteration_5():
    sdk = SDK()
    agent_id = "test_iter_5"
    
    valid_event_id = None
    valid_tool_id = None
    valid_parser_id = None
    
    # 1. Fetch available Events, Tools, and Parsers dynamically
    async with httpx.AsyncClient() as client:
        # Events
        res_ev = await client.get("http://localhost:14321/events/list")
        if res_ev.status_code == 200 and res_ev.json().get('events'):
            valid_event_id = res_ev.json()['events'][0]['id']
            
        # Tools
        res_tool = await client.get("http://localhost:14321/tools/list")
        if res_tool.status_code == 200 and res_tool.json().get('tools'):
            valid_tool_id = res_tool.json()['tools'][0]['id']
            
        # Parsers
        res_parser = await client.get("http://localhost:14321/parsers/list")
        if res_parser.status_code == 200 and res_parser.json().get('parsers'):
            valid_parser_id = res_parser.json()['parsers'][0]['id']

    if not valid_event_id or not valid_tool_id or not valid_parser_id:
        print("❌ [SDK] Missing one of: Event, Tool, or Parser in the database. Please ensure you have at least one of each created in the GUI!")
        return

    print(f"📡 [SDK] Provisioning Persona '{agent_id}' with all features attached...")
    
    await sdk.persona_orchestration.create_persona_async(
        agent_id=agent_id,
        agent_name="The Kitchen Sink Tester",
        model="gemma-3-1b-it-Q5_K_M.gguf",
        system_prompt="You are a helpful assistant.",
        enable_webhook=True,
        
        # Async Routing
        input_topic="massive_inbound_queue",
        output_topic="massive_outbound_queue",
        global_events=[valid_event_id],
        
        # Tools & Vector Stores
        tool_ids=[valid_tool_id],
        vector_store_name="global_knowledge",
        embedding_model_name="embeddinggemma-300m-Q4_0.gguf",
        
        # Interceptors & Parsers
        # input_parser_id=valid_parser_id,
        # output_parser_id=valid_parser_id,
        # tool_call_parser_id=valid_parser_id,
        # tool_response_parser_id=valid_parser_id
        input_parser_id=None,
        output_parser_id=None,
        tool_call_parser_id=None,
        tool_response_parser_id=None
    )
    print("✅ [SDK] Provision successful.")
    
    print(f"🎨 [SDK] Fetching and rendering Canvas PNG...")
    await sdk.persona_orchestration.display_async(id=agent_id)
    print("🤖 [SDK] Invoking Persona with prompt...")
    invoke_response = await sdk.persona_orchestration.invoke_persona_async(
        id=agent_id,
        request_body={
            "query": "Please use the calculate_complex_math tool on the number 10 and tell me the result."
        },
        timeout_ms=120000  # Give it 2 minutes to complete the inference
    )
    print(f"🎉 [SDK] Final Answer from Model: {invoke_response}")
    

await test_iteration_5()
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# 📡 [SDK] Provisioning Persona 'test_iter_5' with all features attached...
# ✅ [SDK] Provision successful.
# 🎨 [SDK] Fetching and rendering Canvas PNG...
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[4], line 81
#      71     invoke_response = await sdk.persona_orchestration.invoke_persona_async(
#      72         id=agent_id,
#      73         request_body={
#    (...)
#      76         timeout_ms=120000  # Give it 2 minutes to complete the inference
#      77     )
#      78     print(f"🎉 [SDK] Final Answer from Model: {invoke_response}")
# ---> 81 await test_iteration_5()
#
# Cell In[4], line 69, in test_iteration_5()
#      66 print("✅ [SDK] Provision successful.")
#      68 print(f"🎨 [SDK] Fetching and rendering Canvas PNG...")
# ...

# %%
# %load_ext autoreload
# %autoreload 2

import asyncio
from ajayji import SDK

async def test_parser_workflow():
    sdk = SDK()
    
    # 1. The Javascript Script you want to test
    test_script = """
    function parse(rawInput) {
      // Example: Parse JSON and extract a nested value
      try {
        const data = JSON.parse(rawInput);
        return "Extracted Value: " + data.exampleKey;
      } catch(e) {
        return "Error parsing JSON: " + e;
      }
    }
    """
    
    # 2. The sample input to test against
    sample_input = '{\n  "exampleKey": "Success via Python SDK!"\n}'
    
    print("🧪 [SDK] Running stateless parser test...")
    # 3. Test the script via the new Test endpoint
    test_response = await sdk.parser_management.test_parser_async(
        script=test_script,
        raw_input=sample_input
    )
    
    print(f"📊 [SDK] Test Result: {test_response.result}")
    print(f"📝 [SDK] Logs: {test_response.logs}")
    
    # 4. If the test succeeded, provision it to the DB!
    if "Success via Python SDK!" in test_response.result:
        print("\n✅ [SDK] Test passed! Provisioning parser record to database...")
        create_response = await sdk.parser_management.create_parser_async(
            name="Jupyter Python Parser",
            description="Created and validated entirely from Jupyter Notebook.",
            script=test_script
        )
        print(f"🎉 [SDK] Parser created with ID: {create_response.id}")

await test_parser_workflow()
# Out:
# 🧪 [SDK] Running stateless parser test...
# 📊 [SDK] Test Result: Extracted Value: Success via Python SDK!
# 📝 [SDK] Logs: []
#
# ✅ [SDK] Test passed! Provisioning parser record to database...
# 🎉 [SDK] Parser created with ID: tf_fb1ddffa-8530-48bb-8de0-48eea156c359

# %%
# %load_ext autoreload
# %autoreload 2

import asyncio
from ajayji import SDK

async def create_persona_with_custom_parser():
    sdk = SDK()
    agent_id = "test_custom_parser_agent"
    
    # 1. Fetch the newly created parser from the database
    print("🔍 [SDK] Fetching available parsers...")
    res_parser = await sdk.parser_management.list_parsers_async()
    
    # Find our specific "Jupyter Python Parser"
    target_parser_id = None
    if res_parser.parsers:
        for parser in res_parser.parsers:
            if parser.name == "Jupyter Python Parser":
                target_parser_id = parser.id
                break
                
    if not target_parser_id:
        print("❌ [SDK] Could not find 'Jupyter Python Parser'. Did Phase 1 succeed?")
        return
        
    print(f"🎯 [SDK] Found target Parser ID: {target_parser_id}")
    print(f"📡 [SDK] Provisioning Persona '{agent_id}' with the custom parser attached to Output...")
    
    # 2. Provision a new Persona that uses our parser on the output!
    await sdk.persona_orchestration.create_persona_async(
        agent_id=agent_id,
        agent_name="Custom Parser Tester",
        model="gemma-3-1b-it-Q5_K_M.gguf",
        system_prompt="You are a helpful assistant.",
        enable_webhook=True,
        
        # Attach our custom parser ONLY to the output
        output_parser_id=target_parser_id
    )
    print("✅ [SDK] Provision successful.")
    
    print(f"🎨 [SDK] Fetching and rendering Canvas PNG...")
    await sdk.persona_orchestration.display_async(id=agent_id)

await create_persona_with_custom_parser()
# Out:
# 🔍 [SDK] Fetching available parsers...
# 🎯 [SDK] Found target Parser ID: tf_fb1ddffa-8530-48bb-8de0-48eea156c359
# 📡 [SDK] Provisioning Persona 'test_custom_parser_agent' with the custom parser attached to Output...
# ✅ [SDK] Provision successful.
# 🎨 [SDK] Fetching and rendering Canvas PNG...

# %%
async def test_invoke_with_parser():
    sdk = SDK()
    agent_id = "test_custom_parser_agent"
    
    print("🤖 [SDK] Invoking Persona to test custom Output Parser...")
    
    # We pass a simple query to the local LLM. 
    # Because we did not attach a tool proxy, the LLM will just respond with standard text.
    # We will specifically ask it to output JSON with an "exampleKey" so our parser can catch it.
    invoke_response = await sdk.persona_orchestration.invoke_persona_async(
        id=agent_id,
        request_body={
            "query": "Please reply with a strictly formatted JSON object containing exactly one key called 'exampleKey', and set its value to 'This was parsed successfully!'"
        },
        timeout_ms=120000
    )
    
    print(f"🎉 [SDK] Final Answer from Model/Parser: {invoke_response}")

await test_invoke_with_parser()
# Out:
# 🤖 [SDK] Invoking Persona to test custom Output Parser...
# 🎉 [SDK] Final Answer from Model/Parser: response="Error parsing JSON: SyntaxError: JSON Parse error: Unrecognized token '<'"

# %%
# %load_ext autoreload
# %autoreload 2

import asyncio
from ajayji import SDK

async def update_parser_script():
    sdk = SDK()
    
    # 1. Fetch our target parser ID
    print("🔍 [SDK] Fetching available parsers to update...")
    res_parser = await sdk.parser_management.list_parsers_async()
    
    target_parser_id = None
    if res_parser.parsers:
        for parser in res_parser.parsers:
            if parser.name == "Jupyter Python Parser":
                target_parser_id = parser.id
                break
                
    if not target_parser_id:
        print("❌ [SDK] Could not find 'Jupyter Python Parser'.")
        return
        
    print(f"🎯 [SDK] Updating Parser ID: {target_parser_id}")
    
    # 2. The robust Javascript Script (strips markdown fences)
    robust_script = """
    function parse(rawInput) {
      try {
        // Strip markdown json fences and trim whitespace
        const cleaned = rawInput.replace(/```(json)?|```/g, '').trim();
        const data = JSON.parse(cleaned);
        return "Extracted Value: " + data.exampleKey;
      } catch(e) {
        return "Error parsing JSON: " + e;
      }
    }
    """
    
    # 3. We use the create_parser_async endpoint, but because we are passing the 
    # exact same name, it should logically just be an update. 
    # NOTE: Our current Dart logic assigns a NEW UUID every time we hit POST /parsers! 
    # So we are actually creating a new parser. 
    # To use it, we must re-provision the agent.
    
    print("\n✅ [SDK] Provisioning updated parser record to database...")
    create_response = await sdk.parser_management.create_parser_async(
        name="Jupyter Python Parser Robust",
        description="Robust version that strips markdown fences.",
        script=robust_script
    )
    new_parser_id = create_response.id
    print(f"🎉 [SDK] New Robust Parser created with ID: {new_parser_id}")
    
    # 4. Update the Persona to use the robust parser
    print(f"📡 [SDK] Re-provisioning Persona with robust Output Parser...")
    agent_id = "test_custom_parser_agent"
    await sdk.persona_orchestration.create_persona_async(
        agent_id=agent_id,
        agent_name="Custom Parser Tester",
        model="gemma-3-1b-it-Q5_K_M.gguf",
        system_prompt="You are a helpful assistant.",
        enable_webhook=True,
        output_parser_id=new_parser_id
    )
    print("✅ [SDK] Re-provision successful.")

await update_parser_script()
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
# 🔍 [SDK] Fetching available parsers to update...
# 🎯 [SDK] Updating Parser ID: tf_fb1ddffa-8530-48bb-8de0-48eea156c359
#
# ✅ [SDK] Provisioning updated parser record to database...
# 🎉 [SDK] New Robust Parser created with ID: tf_c00fa0c6-206c-471a-b6a9-77d32e185e63
# 📡 [SDK] Re-provisioning Persona with robust Output Parser...
# ✅ [SDK] Re-provision successful.

# %%
# %load_ext autoreload
# %autoreload 2

import asyncio
from ajayji import SDK

async def update_parser_script_final():
    sdk = SDK()
        
    # The ultimate robust script. Uses regex to extract the first { ... } block
    ultimate_script = """
    function parse(rawInput) {
      try {
        // Find the first occurrence of { and the last occurrence of }
        const startIndex = rawInput.indexOf('{');
        const endIndex = rawInput.lastIndexOf('}');
        
        if (startIndex === -1 || endIndex === -1 || endIndex < startIndex) {
            return "Error: No JSON object found in output.";
        }
        
        const jsonString = rawInput.substring(startIndex, endIndex + 1);
        const data = JSON.parse(jsonString);
        return "Extracted Value: " + data.exampleKey;
      } catch(e) {
        return "Error parsing JSON: " + e;
      }
    }
    """
    
    print("\n✅ [SDK] Provisioning ULTIMATE parser record to database...")
    create_response = await sdk.parser_management.create_parser_async(
        name="Jupyter Python Parser Ultimate",
        description="Extracts JSON block natively, ignoring control tokens and markdown.",
        script=ultimate_script
    )
    new_parser_id = create_response.id
    print(f"🎉 [SDK] New Ultimate Parser created with ID: {new_parser_id}")
    
    print(f"📡 [SDK] Re-provisioning Persona with ultimate Output Parser...")
    agent_id = "test_custom_parser_agent"
    await sdk.persona_orchestration.create_persona_async(
        agent_id=agent_id,
        agent_name="Custom Parser Tester",
        model="gemma-3-1b-it-Q5_K_M.gguf",
        system_prompt="You are a helpful assistant.",
        enable_webhook=True,
        output_parser_id=new_parser_id
    )
    print("✅ [SDK] Re-provision successful.")

await update_parser_script_final()
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload
#
# ✅ [SDK] Provisioning ULTIMATE parser record to database...
# 🎉 [SDK] New Ultimate Parser created with ID: tf_1595573d-b25b-4008-9a7f-59fe5ddadd3a
# 📡 [SDK] Re-provisioning Persona with ultimate Output Parser...
# ✅ [SDK] Re-provision successful.

# %%
async def test_invoke_with_parser():
    sdk = SDK()
    agent_id = "test_custom_parser_agent"
    
    print("🤖 [SDK] Invoking Persona to test custom Output Parser...")
    
    # We pass a simple query to the local LLM. 
    # Because we did not attach a tool proxy, the LLM will just respond with standard text.
    # We will specifically ask it to output JSON with an "exampleKey" so our parser can catch it.
    invoke_response = await sdk.persona_orchestration.invoke_persona_async(
        id=agent_id,
        request_body={
            "query": "Please reply with a strictly formatted JSON object containing exactly one key called 'exampleKey', and set its value to 'This was parsed successfully!'"
        },
        timeout_ms=120000
    )
    
    print(f"🎉 [SDK] Final Answer from Model/Parser: {invoke_response}")

await test_invoke_with_parser()
# Out:
# 🤖 [SDK] Invoking Persona to test custom Output Parser...
# 🎉 [SDK] Final Answer from Model/Parser: response='Extracted Value: This was parsed successfully!'
